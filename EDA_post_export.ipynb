# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_init = pd.read_csv(
    "posts-export-by-page-views-Feb-01-2025-Mar-05-2026-Masthead-Maine.csv"
)
df_init.head(20)
# Out:
#               Apikey                                                URL  \
# 0    pressherald.com                        https://www.pressherald.com
# 1   centralmaine.com                       https://www.centralmaine.com
# 2    pressherald.com             http://www.pressherald.com/obituaries/
# 3     sunjournal.com                         https://www.sunjournal.com
# 4   centralmaine.com           https://www.centralmaine.com/obituaries/
# 5     sunjournal.com             https://www.sunjournal.com/obituaries/
# 6    pressherald.com      http://www.pressherald.com/obituaries/page/2/
# 7    pressherald.com                 http://www.pressherald.com/epaper/
# 8     sunjournal.com                 https://www.sunjournal.com/epaper/
# 9   centralmaine.com    https://www.centralmaine.com/obituaries/page/2/
# 10   pressherald.com      http://www.pressherald.com/obituaries/page/3/
# 11    sunjournal.com      https://www.sunjournal.com/obituaries/page/2/
# ...

# %%
unique_urls = df_init["URL"].unique()
print(len(unique_urls))
print(len(unique_urls) / df_init.shape[0])
# Out:
# 10000
# 1.0

# %%
print(df_init['Tags'].nunique())
print(df_init["Tags"].unique())
# Out:
# 7875
# [nan
#  'gray,local & state,location: gray,news,portland press herald,user_need: update-me'
#  'auburn,augusta,bangor,local & state,portland,portland press herald,rockland,social security'
#  ...
#  'camden,camden hills windjammers,falmouth,falmouth navigators,portland,portland press herald,rockport,saco,sports,tennis,thornton golden trojans,varsity maine,waynflete flyers,yarmouth,yarmouth clippers'
#  'buckfield,buckfield bucks,north yarmouth,nya panthers,softball,sports,sun journal,varsity maine'
#  'cops & courts,local & state,nation & world,news']

# %%
print(df_init["High-Level Smart Tags"].nunique())
print(df_init["High-Level Smart Tags"].unique())
# Out:
# 991
# [nan 'Law, Gov’t & Politics,Legal Issues' 'Health & Fitness'
#  'Christianity,Religion & Spirituality' 'Cancer,Health & Fitness'
#  'Business,Law, Gov’t & Politics,Legal Issues,Science,Weather'
#  'Health & Fitness,Law, Gov’t & Politics' 'Law, Gov’t & Politics'
#  'Law, Gov’t & Politics,Legal Issues,Technology'
#  'Babies & Toddlers,Family & Parenting,Health & Fitness,Law, Gov’t & Politics,Legal Issues,Pediatrics'
#  'Business,Law, Gov’t & Politics' 'Immigration,Law, Gov’t & Politics'
#  'Law, Gov’t & Politics,Legal Issues,Politics' 'Science,Weather'
#  'Arts & Entertainment,Guitar,Music' 'Law, Gov’t & Politics,Politics'
#  'Credit, Debt & Loans,Finance,Law, Gov’t & Politics,Real Estate'
#  'Alcohol,Arts & Entertainment,Dining Out,Food & Drink,Music'
#  'College Administration,Education,Law, Gov’t & Politics'
#  'Beauty,Style & Fashion' 'Immigration,Law, Gov’t & Politics,Legal Issues'
#  'Technology' 'Alcohol,Dining Out,Food & Drink,Society,Weddings'
# ...

# %%
print(df_init["Low-Level Smart Tags"].nunique())
print(df_init["Low-Level Smart Tags"].unique())
# Out:
# 5058
# [nan
#  'Arundel, Maine,Cape Elizabeth, Maine,Falmouth, Maine,Gorham, Maine,Portland Press Herald,Portland, Maine,Raymond, Maine,Scarborough, Maine,Sebago, Maine,South Portland, Maine,Standish, Maine,Windham, Maine'
#  'George Santos' ...
#  'Donald Trump,Mike Johnson,Republican Party (United States)'
#  'John Joubert (serial killer),Judge,Jury,Law,Nebraska Supreme Court,Supreme Court of the United States'
#  'Arrest,Long Island serial killer']
